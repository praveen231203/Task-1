# %%
import pandas as pd
df=pd.read_csv('Amazon Sale Report_intern.csv',low_memory=False)
df
# Out:
#         index             Order ID      Date                        Status  \
# 0         0.0  405-8078784-5731545  04-30-22                     Cancelled
# 1         1.0  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2         2.0  404-0687676-7273146  04-30-22                       Shipped
# 3         3.0  403-9615377-8133951  04-30-22                     Cancelled
# 4         4.0  407-1069790-7240320  04-30-22                       Shipped
# ...       ...                  ...       ...                           ...
# 128970    NaN                  NaN       NaN                           NaN
# 128971    NaN                  NaN       NaN                           NaN
# 128972    NaN                  NaN       NaN                           NaN
# 128973    NaN                  NaN       NaN                           NaN
# 128974    NaN  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.isnull()
# Out:
#         index  Order ID   Date  Status  Fulfilment  Sales Channel   \
# 0       False     False  False   False       False           False
# 1       False     False  False   False       False           False
# 2       False     False  False   False       False           False
# 3       False     False  False   False       False           False
# 4       False     False  False   False       False           False
# ...       ...       ...    ...     ...         ...             ...
# 128970   True      True   True    True        True            True
# 128971   True      True   True    True        True            True
# 128972   True      True   True    True        True            True
# 128973   True      True   True    True        True            True
# 128974   True     False  False   False       False           False
#
#         ship-service-level  Style    SKU  Category  ...  currency  Amount  \
# 0                    False  False  False     False  ...     False   False
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [index, Order ID, Date, Status, Fulfilment, Sales Channel , ship-service-level, Style, SKU, Category, Size, ASIN, Courier Status, Qty, currency, Amount, ship-city, ship-state, ship-postal-code, ship-country, promotion-ids, B2B, fulfilled-by, Unnamed: 22]
# Index: []
#
# [0 rows x 24 columns]

# %%
df.isnull().sum()          # Nulls per column
df.isnull().sum().sum()    # Total nulls in DataFrame
# Out:
# np.int64(2986615)

# %%
df = df.drop_duplicates()
df
# Out:
#          index             Order ID      Date                        Status  \
# 0          0.0  405-8078784-5731545  04-30-22                     Cancelled
# 1          1.0  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2          2.0  404-0687676-7273146  04-30-22                       Shipped
# 3          3.0  403-9615377-8133951  04-30-22                     Cancelled
# 4          4.0  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 4995    4995.0  405-9036147-3522705  04-27-22                       Shipped
# 4996    4996.0  405-5485616-5052346  04-27-22  Shipped - Delivered to Buyer
# 4997    4997.0  408-0187324-2986712  04-27-22  Shipped - Delivered to Buyer
# 4998       NaN                  NaN       NaN                           NaN
# 128974     NaN  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df.drop_duplicates(inplace=True)
df
# Out:
#          index             Order ID      Date                        Status  \
# 0          0.0  405-8078784-5731545  04-30-22                     Cancelled
# 1          1.0  171-9198151-1101146  04-30-22  Shipped - Delivered to Buyer
# 2          2.0  404-0687676-7273146  04-30-22                       Shipped
# 3          3.0  403-9615377-8133951  04-30-22                     Cancelled
# 4          4.0  407-1069790-7240320  04-30-22                       Shipped
# ...        ...                  ...       ...                           ...
# 4995    4995.0  405-9036147-3522705  04-27-22                       Shipped
# 4996    4996.0  405-5485616-5052346  04-27-22  Shipped - Delivered to Buyer
# 4997    4997.0  408-0187324-2986712  04-27-22  Shipped - Delivered to Buyer
# 4998       NaN                  NaN       NaN                           NaN
# 128974     NaN  408-7436540-8728312  05-31-22                       Shipped
#
# ...

# %%
df['Date'] = pd.to_datetime(df['Date'],format='dd-mm-yyyy')
df
# Out:
#          index             Order ID       Date                        Status  \
# 0          0.0  405-8078784-5731545 2022-04-30                     Cancelled
# 1          1.0  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2          2.0  404-0687676-7273146 2022-04-30                       Shipped
# 3          3.0  403-9615377-8133951 2022-04-30                     Cancelled
# 4          4.0  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 4995    4995.0  405-9036147-3522705 2022-04-27                       Shipped
# 4996    4996.0  405-5485616-5052346 2022-04-27  Shipped - Delivered to Buyer
# 4997    4997.0  408-0187324-2986712 2022-04-27  Shipped - Delivered to Buyer
# 4998       NaN                  NaN        NaT                           NaN
# 128974     NaN  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
df.to_csv('Cleaned_Amazon_Sale.csv', index=False)

# %%
import numpy as np
df.replace ('',np.nan,inplace=True)
df
# Out:
#          index             Order ID       Date                        Status  \
# 0          0.0  405-8078784-5731545 2022-04-30                     Cancelled
# 1          1.0  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2          2.0  404-0687676-7273146 2022-04-30                       Shipped
# 3          3.0  403-9615377-8133951 2022-04-30                     Cancelled
# 4          4.0  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 4995    4995.0  405-9036147-3522705 2022-04-27                       Shipped
# 4996    4996.0  405-5485616-5052346 2022-04-27  Shipped - Delivered to Buyer
# 4997    4997.0  408-0187324-2986712 2022-04-27  Shipped - Delivered to Buyer
# 4998       NaN                  NaN        NaT                           NaN
# 128974     NaN  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
df.drop_duplicates()
df
# Out:
#          index             Order ID       Date                        Status  \
# 0          0.0  405-8078784-5731545 2022-04-30                     Cancelled
# 1          1.0  171-9198151-1101146 2022-04-30  Shipped - Delivered to Buyer
# 2          2.0  404-0687676-7273146 2022-04-30                       Shipped
# 3          3.0  403-9615377-8133951 2022-04-30                     Cancelled
# 4          4.0  407-1069790-7240320 2022-04-30                       Shipped
# ...        ...                  ...        ...                           ...
# 4995    4995.0  405-9036147-3522705 2022-04-27                       Shipped
# 4996    4996.0  405-5485616-5052346 2022-04-27  Shipped - Delivered to Buyer
# 4997    4997.0  408-0187324-2986712 2022-04-27  Shipped - Delivered to Buyer
# 4998       NaN                  NaN        NaT                           NaN
# 128974     NaN  408-7436540-8728312 2022-05-31                       Shipped
#
# ...

# %%
before = len(df)
df = df.drop_duplicates()
after = len(df)

print(f'Dropped {before - after} duplicate rows')
# Out:
# Dropped 0 duplicate rows

# %%
df.to_csv('Cleaned_Sale.csv' , index=False)

# %%
import pandas as pd
df = pd.read_csv('Cleaned_Sale.csv')  # since it's really a CSV
df.to_csv('Cleaned_Amazon.csv', index=False)

# %%
import pandas as pd

# Load the CSV (your file is comma-delimited, so this works)
df = pd.read_csv('Cleaned_Amazon.csv')

# Optional: drop unnamed columns or clean columns here
df = df.loc[:, ~df.columns.str.contains('^Unnamed')]  # Removes empty last column

# Save it as actual Excel file
df.to_excel('cleaned_file.xlsx', index=False)

# Create download link (Jupyter Notebook)
from IPython.display import FileLink
FileLink('cleaned_file.xlsx')
# Out:
# C:\Users\praveen\cleaned_file.xlsx
